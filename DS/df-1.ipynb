# %%
# dataframes - 2D 
import pandas as pd

# %%
df= pd.DataFrame([12,13,22,21,10,7])
df
# Out:
#     0
# 0  12
# 1  13
# 2  22
# 3  21
# 4  10
# 5   7

# %%
df.shape
# Out:
# (6, 1)

# %%
df1= pd.DataFrame({'name':['Karan','Anmol','Aman','Nakul','Rohit','Mohit'],'class':['btech','bca','mba','mca','bca','btech'],'rollno':[12,11,14,10,5,8]})
df1
# Out:
#     name  class  rollno
# 0  Karan  btech      12
# 1  Anmol    bca      11
# 2   Aman    mba      14
# 3  Nakul    mca      10
# 4  Rohit    bca       5
# 5  Mohit  btech       8

# %%
df1.shape
# Out:
# (6, 3)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   class   6 non-null      object
#  2   rollno  6 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 276.0+ bytes

# %%
df1.columns
# Out:
# Index(['name', 'class', 'rollno'], dtype='object')

# %%
# access -[], . , loc, iloc

# %%
df1['name']
# Out:
# 0    Karan
# 1    Anmol
# 2     Aman
# 3    Nakul
# 4    Rohit
# 5    Mohit
# Name: name, dtype: object

# %%
df1[:]
# Out:
#     name  class  rollno
# 0  Karan  btech      12
# 1  Anmol    bca      11
# 2   Aman    mba      14
# 3  Nakul    mca      10
# 4  Rohit    bca       5
# 5  Mohit  btech       8

# %%
df1[:2]
# Out:
#     name  class  rollno
# 0  Karan  btech      12
# 1  Anmol    bca      11

# %%
df1[1:6]
# Out:
#     name  class  rollno
# 1  Anmol    bca      11
# 2   Aman    mba      14
# 3  Nakul    mca      10
# 4  Rohit    bca       5
# 5  Mohit  btech       8

# %%
df1['name'][:3]
# Out:
# 0    Karan
# 1    Anmol
# 2     Aman
# Name: name, dtype: object

# %%
df1['class'][4]
# Out:
# 'bca'

# %%
df1.name[2]
# Out:
# 'Aman'

# %%
df1[['name','rollno']]
# Out:
#     name  rollno
# 0  Karan      12
# 1  Anmol      11
# 2   Aman      14
# 3  Nakul      10
# 4  Rohit       5
# 5  Mohit       8

# %%
# loc,iloc

# %%
df1.loc[:,:]  # rows,columns
# Out:
#     name  class  rollno
# 0  Karan  btech      12
# 1  Anmol    bca      11
# 2   Aman    mba      14
# 3  Nakul    mca      10
# 4  Rohit    bca       5
# 5  Mohit  btech       8

# %%
df1.loc[:3,:]
# Out:
#     name  class  rollno
# 0  Karan  btech      12
# 1  Anmol    bca      11
# 2   Aman    mba      14
# 3  Nakul    mca      10

# %%
df1.iloc[:3,:]
# Out:
#     name  class  rollno
# 0  Karan  btech      12
# 1  Anmol    bca      11
# 2   Aman    mba      14

# %%
df1.loc[:,'name']
# Out:
# 0    Karan
# 1    Anmol
# 2     Aman
# 3    Nakul
# 4    Rohit
# 5    Mohit
# Name: name, dtype: object

# %%
df1.loc[:,['name']]
# Out:
#     name
# 0  Karan
# 1  Anmol
# 2   Aman
# 3  Nakul
# 4  Rohit
# 5  Mohit

# %%
df1.loc[:,['name','rollno']]
# Out:
#     name  rollno
# 0  Karan      12
# 1  Anmol      11
# 2   Aman      14
# 3  Nakul      10
# 4  Rohit       5
# 5  Mohit       8

# %%
df1.iloc[:,:2]
# Out:
#     name  class
# 0  Karan  btech
# 1  Anmol    bca
# 2   Aman    mba
# 3  Nakul    mca
# 4  Rohit    bca
# 5  Mohit  btech

# %%
df1.loc[2,'name']
# Out:
# 'Aman'

# %%
df1.loc[2,:]
# Out:
# name      Aman
# class      mba
# rollno      14
# Name: 2, dtype: object

# %%
# update row, column and value

# %%
df1.loc[3,'class']='bba'

# %%
df1
# Out:
#     name  class  rollno
# 0  Karan  btech      12
# 1  Anmol    bca      11
# 2   Aman    mba      14
# 3  Nakul    bba      10
# 4  Rohit    bca       5
# 5  Mohit  btech       8

# %%
df1.loc[:,'total_marks']=40

# %%
df1
# Out:
#     name  class  rollno  total_marks
# 0  Karan  btech      12           40
# 1  Anmol    bca      11           40
# 2   Aman    mba      14           40
# 3  Nakul    bba      10           40
# 4  Rohit    bca       5           40
# 5  Mohit  btech       8           40

# %%
df1.loc[:,'marks']=[32,35,29,28,37,38]

# %%
df1
# Out:
#     name  class  rollno  total_marks  marks
# 0  Karan  btech      12           40     32
# 1  Anmol    bca      11           40     35
# 2   Aman    mba      14           40     29
# 3  Nakul    bba      10           40     28
# 4  Rohit    bca       5           40     37
# 5  Mohit  btech       8           40     38

# %%
df1.insert(loc=3,column='age', value=[23,24,22,21,25,19])

# %%
df1
# Out:
#     name  class  rollno  age  total_marks  marks
# 0  Karan  btech      12   23           40     32
# 1  Anmol    bca      11   24           40     35
# 2   Aman    mba      14   22           40     29
# 3  Nakul    bba      10   21           40     28
# 4  Rohit    bca       5   25           40     37
# 5  Mohit  btech       8   19           40     38

# %%
# rename column name 
df1.rename(columns={'class':'degree'},inplace=True)

# %%
df1
# Out:
#     name degree  rollno  age  total_marks  marks
# 0  Karan  btech      12   23           40     32
# 1  Anmol    bca      11   24           40     35
# 2   Aman    mba      14   22           40     29
# 3  Nakul    bba      10   21           40     28
# 4  Rohit    bca       5   25           40     37
# 5  Mohit  btech       8   19           40     38

# %%
df1.loc[:,'percentage']= (df1.loc[:,'marks']/df1.loc[:,'total_marks'])*100

# %%
df1
# Out:
#     name degree  rollno  age  total_marks  marks  percentage
# 0  Karan  btech      12   23           40     32        80.0
# 1  Anmol    bca      11   24           40     35        87.5
# 2   Aman    mba      14   22           40     29        72.5
# 3  Nakul    bba      10   21           40     28        70.0
# 4  Rohit    bca       5   25           40     37        92.5
# 5  Mohit  btech       8   19           40     38        95.0

# %%
# conditions 
df1[df1.loc[:,'degree']=='bca']
# Out:
#     name degree  rollno  age  total_marks  marks  percentage
# 1  Anmol    bca      11   24           40     35        87.5
# 4  Rohit    bca       5   25           40     37        92.5

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         6 non-null      object
#  1   degree       6 non-null      object
#  2   rollno       6 non-null      int64
#  3   age          6 non-null      int64
#  4   total_marks  6 non-null      int64
#  5   marks        6 non-null      int64
#  6   percentage   6 non-null      float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 468.0+ bytes

# %%
df1.describe()
# Out:
#           rollno        age  total_marks      marks  percentage
# count   6.000000   6.000000          6.0   6.000000    6.000000
# mean   10.000000  22.333333         40.0  33.166667   82.916667
# std     3.162278   2.160247          0.0   4.167333   10.418333
# min     5.000000  19.000000         40.0  28.000000   70.000000
# 25%     8.500000  21.250000         40.0  29.750000   74.375000
# 50%    10.500000  22.500000         40.0  33.500000   83.750000
# 75%    11.750000  23.750000         40.0  36.500000   91.250000
# max    14.000000  25.000000         40.0  38.000000   95.000000
