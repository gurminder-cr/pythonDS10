# %%
import pandas as pd 
s= pd.Series([13,33,21,36,43,22,16,56,78])

# %%
s
# Out:
# 0    13
# 1    33
# 2    21
# 3    36
# 4    43
# 5    22
# 6    16
# 7    56
# 8    78
# dtype: int64

# %%
s>30
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# 8     True
# dtype: bool

# %%
s[s>30]
# Out:
# 1    33
# 3    36
# 4    43
# 7    56
# 8    78
# dtype: int64

# %%
s[(s>30) & (s<70)]
# Out:
# 1    33
# 3    36
# 4    43
# 7    56
# dtype: int64

# %%
# between function 
s[s.between(30,70)]
# Out:
# 1    33
# 3    36
# 4    43
# 7    56
# dtype: int64

# %%
s[s==43]
# Out:
# 4    43
# dtype: int64

# %%
s[s.isin([43])]
# Out:
# 4    43
# dtype: int64

# %%
# series update or add values, delete
s
# Out:
# 0    13
# 1    33
# 2    21
# 3    36
# 4    43
# 5    22
# 6    16
# 7    56
# 8    78
# dtype: int64

# %%
s.loc[9]=100

# %%
s
# Out:
# 0     13
# 1     33
# 2     21
# 3     36
# 4     43
# 5     22
# 6     16
# 7     56
# 8     78
# 9    100
# dtype: int64

# %%
s.loc[4]=50

# %%
s
# Out:
# 0     13
# 1     33
# 2     21
# 3     36
# 4     50
# 5     22
# 6     16
# 7     56
# 8     78
# 9    100
# dtype: int64

# %%
# delete 
s.drop(labels=4)
# Out:
# 0     13
# 1     33
# 2     21
# 3     36
# 5     22
# 6     16
# 7     56
# 8     78
# 9    100
# dtype: int64

# %%
# delete 
s.drop(labels=4,inplace=True)

# %%
s
# Out:
# 0     13
# 1     33
# 2     21
# 3     36
# 5     22
# 6     16
# 7     56
# 8     78
# 9    100
# dtype: int64

# %%
# maths 
s.sum()
# Out:
# 375

# %%
s.max()
# Out:
# 100

# %%
s.min()
# Out:
# 13

# %%
s.mean()
# Out:
# 41.666666666666664

# %%
s=s.map(lambda x:x*10)

# %%
s
# Out:
# 0     130
# 1     330
# 2     210
# 3     360
# 5     220
# 6     160
# 7     560
# 8     780
# 9    1000
# dtype: int64

# %%
def funcs(x):
    return x/5

s=s.map(funcs)

# %%
s
# Out:
# 0     26.0
# 1     66.0
# 2     42.0
# 3     72.0
# 5     44.0
# 6     32.0
# 7    112.0
# 8    156.0
# 9    200.0
# dtype: float64

# %%
s.shape
# Out:
# (9,)

# %%
s.dtype
# Out:
# dtype('float64')

# %%
s=s.astype('int')

# %%
s
# Out:
# 0     26
# 1     66
# 2     42
# 3     72
# 5     44
# 6     32
# 7    112
# 8    156
# 9    200
# dtype: int32

# %%
# find nan values in Series
# create nan (null values) in series 
# solve
