# %%
print("Hello")
# Out:
# Hello

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
def func1(a,b):
    return a+b

# %%
print(func1(11,12))
10
# Out:
# 23
# 10

# %%
11*12
# Out:
# 132

# %%
# series, dataframes
# Data Science
